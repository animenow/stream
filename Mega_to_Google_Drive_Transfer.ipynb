# %% [markdown]
# #`Mount/Unmount Google drive(`<font size="3px" color="#01c968">`Gdrive`</font>`)`

# %%
#@markdown <br><center><img src='https://upload.wikimedia.org/wikipedia/commons/thumb/d/da/Google_Drive_logo.png/600px-Google_Drive_logo.png' height="50" alt="Gdrive-logo"/></center>
#@markdown <center><h3>Mount Gdrive to /content/drive</h3></center><br>
MODE = "MOUNT" #@param ["MOUNT", "UNMOUNT"]
#Mount your Gdrive! 
from google.colab import drive
drive.mount._DEBUG = False
if MODE == "MOUNT":
  drive.mount('/content/drive', force_remount=True)
elif MODE == "UNMOUNT":
  try:
    drive.flush_and_unmount()
  except ValueError:
    pass
  get_ipython().system_raw("rm -rf /root/.config/Google/DriveFS")
# Out:
# Mounted at /content/drive

# %% [markdown]
# #`Mega to Google Drive transfer`

# %%
# @markdown <center><h3>Enter your Mega Account Details</h3></center><br>
# https://github.com/surajbahadur591

from functools import wraps
import errno
import os
import signal
import subprocess
import shlex

#@markdown <h3>Step 1 : Mega installation</h3></center><br>

class TimeoutError(Exception):
    pass


def timeout(seconds=10, error_message=os.strerror(errno.ETIME)):
    def decorator(func):
        def _handle_timeout(signum, frame):
            raise TimeoutError(error_message)

        def wrapper(*args, **kwargs):
            signal.signal(signal.SIGALRM, _handle_timeout)
            signal.alarm(seconds)
            try:
                result = func(*args, **kwargs)
            finally:
                signal.alarm(0)
            return result

        return wraps(func)(wrapper)

    return decorator


if not os.path.exists("/root/.ipython/ocr.py"):
    from subprocess import run
    from shlex import split

    shellCmd = "wget -qq https://raw.githubusercontent.com/biplobsd/OneClickRun/master/res/ocr.py \
                    -O /root/.ipython/ocr.py"
    run(split(shellCmd))
from ocr import runSh

@timeout(10)
def runShT(args):
    return runSh(args, output=True)


# MEGAcmd installing
if not os.path.exists("/usr/bin/mega-cmd"):
    print("Installing MEGA ...")
    runSh('sudo apt-get -y update')
    runSh('sudo apt-get -y install libmms0 libc-ares2 libc6 libcrypto++6 libgcc1 libmediainfo0v5 libpcre3 libpcrecpp0v5 libssl1.1 libstdc++6 libzen0v5 zlib1g apt-transport-https')
    runSh('sudo curl -sL -o /var/cache/apt/archives/MEGAcmd.deb https://mega.nz/linux/MEGAsync/Debian_9.0/amd64/megacmd-Debian_9.0_amd64.deb', output=True)
    runSh('sudo dpkg -i /var/cache/apt/archives/MEGAcmd.deb', output=True)
    print("MEGA is installed.")
else:
    # !pkill mega-cmd

# INPUT YOUR MEGA ID

USERNAME = ""  # @param {type:"string"}
PASSWORD = ""  # @param {type:"string"}
if not (USERNAME == "" or PASSWORD == ""):
    try:
        runShT(f"mega-login {USERNAME} {PASSWORD}")
    except TimeoutError:
        runSh('mega-whoami', output=True)
else:
    print("Please Input your Mega IDs.")
# @markdown *Use your mega account to avoid any limit*

# %%
import sys, os, urllib.request
import time
import subprocess
import contextlib
from IPython.display import clear_output
#@markdown <br><center><img src='https://i.imgur.com/5AzebjC.png' height="250" alt="MEGA-logo"/></center>
#@markdown <center><h2>Transfer from Mega to GDrive</h2></center><br>
HOME = os.path.expanduser("~")
if not os.path.exists(f"{HOME}/.ipython/ocr.py"):
    hCode = "https://raw.githubusercontent.com/biplobsd/" \
                "OneClickRun/master/res/ocr.py"
    urllib.request.urlretrieve(hCode, f"{HOME}/.ipython/ocr.py")

from ocr import (
    runSh,
    loadingAn,
)
#@title MEGA public link download

#@markdown <h3>Step 2 : Input Source and Destination path</h3></center><br>

COPY_MEGA_URL = "https://mega.nz/file/IZwWnQAA#5I7S050VRwxigjrPEwM1N0ESNWRXEOSTFGGrnfWNty4" #@param {type:"string"}
OUTPUT_PATH_OF_GDRIVE = "/content/drive/Shareddrives/Drive 2/Miraculous" #@param {type:"string"}
if not OUTPUT_PATH_OF_GDRIVE:
  os.makedirs("downloads", exist_ok=True)
  OUTPUT_PATH_OF_GDRIVE = "downloads"
# MEGAcmd installing
if not os.path.exists("/usr/bin/mega-cmd"):
    loadingAn()
    print("Installing MEGA ...")
    runSh('sudo apt-get -y update')
    runSh('sudo apt-get -y install libmms0 libc-ares2 libc6 libcrypto++6 libgcc1 libmediainfo0v5 libpcre3 libpcrecpp0v5 libssl1.1 libstdc++6 libzen0v5 zlib1g apt-transport-https')
    runSh('sudo curl -sL -o /var/cache/apt/archives/MEGAcmd.deb https://mega.nz/linux/MEGAsync/Debian_9.0/amd64/megacmd-Debian_9.0_amd64.deb', output=True)
    runSh('sudo dpkg -i /var/cache/apt/archives/MEGAcmd.deb', output=True)
    print("MEGA is installed.")
    clear_output()

# Unix, Windows and old Macintosh end-of-line
newlines = ['\n', '\r\n', '\r']

def unbuffered(proc, stream='stdout'):
    stream = getattr(proc, stream)
    with contextlib.closing(stream):
        while True:
            out = []
            last = stream.read(1)
            # Don't loop forever
            if last == '' and proc.poll() is not None:
                break
            while last not in newlines:
                # Don't loop forever
                if last == '' and proc.poll() is not None:
                    break
                out.append(last)
                last = stream.read(1)
            out = ''.join(out)
            yield out


def transfare():
    import codecs
    decoder = codecs.getincrementaldecoder("UTF-8")()
    cmd = ["mega-get", COPY_MEGA_URL, OUTPUT_PATH_OF_GDRIVE]
    proc = subprocess.Popen(
        cmd,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        # Make all end-of-lines '\n'
        universal_newlines=True,
    )
    for line in unbuffered(proc):
        print(line)
        


transfare()
# Out:
# [Initiating server in background. Log: /root/.megaCmd/megacmdserver.log]
# TRANSFERRING ||#.........................................||(0/314 MB:   0.12 %)
# TRANSFERRING ||#.........................................||(0/314 MB:   0.23 %)
# TRANSFERRING ||#.........................................||(0/314 MB:   0.26 %)
# TRANSFERRING ||#.........................................||(1/314 MB:   0.47 %)
# TRANSFERRING ||#.........................................||(1/314 MB:   0.54 %)
# TRANSFERRING ||#.........................................||(1/314 MB:   0.57 %)
# TRANSFERRING ||#.........................................||(3/314 MB:   1.09 %)
# TRANSFERRING ||#.........................................||(4/314 MB:   1.56 %)
# TRANSFERRING ||#.........................................||(6/314 MB:   2.04 %)
# TRANSFERRING ||#.........................................||(6/314 MB:   2.12 %)
# TRANSFERRING ||##........................................||(8/314 MB:   2.82 %)
# TRANSFERRING ||##.......................................||(11/314 MB:   3.76 %)
# TRANSFERRING ||##.......................................||(14/314 MB:   4.64 %)
# TRANSFERRING ||###......................................||(17/314 MB:   5.69 %)
# TRANSFERRING ||####.....................................||(23/314 MB:   7.48 %)
# TRANSFERRING ||####.....................................||(27/314 MB:   8.62 %)
# TRANSFERRING ||#####....................................||(31/314 MB:  10.11 %)
# TRANSFERRING ||#####....................................||(36/314 MB:  11.46 %)
# TRANSFERRING ||######...................................||(41/314 MB:  13.16 %)
# TRANSFERRING ||######...................................||(45/314 MB:  14.30 %)
# TRANSFERRING ||#######..................................||(49/314 MB:  15.70 %)
# TRANSFERRING ||########.................................||(53/314 MB:  17.08 %)
# TRANSFERRING ||########.................................||(58/314 MB:  18.68 %)
# TRANSFERRING ||#########................................||(62/314 MB:  19.80 %)
# TRANSFERRING ||#####....................................||(31/314 MB:  10.00 %)
# TRANSFERRING ||#######..................................||(47/314 MB:  15.10 %)
# TRANSFERRING ||#########................................||(63/314 MB:  20.19 %)
# TRANSFERRING ||#########................................||(65/314 MB:  20.75 %)
# TRANSFERRING ||#########................................||(67/314 MB:  21.49 %)
# TRANSFERRING ||##########...............................||(71/314 MB:  22.82 %)
# TRANSFERRING ||##########...............................||(76/314 MB:  24.34 %)
# TRANSFERRING ||###########..............................||(80/314 MB:  25.67 %)
# TRANSFERRING ||############.............................||(85/314 MB:  27.20 %)
# TRANSFERRING ||############.............................||(88/314 MB:  28.15 %)
# TRANSFERRING ||#############............................||(93/314 MB:  29.68 %)
# TRANSFERRING ||#############............................||(98/314 MB:  31.20 %)
# TRANSFERRING ||#############...........................||(101/314 MB:  32.33 %)
# TRANSFERRING ||##############..........................||(106/314 MB:  33.81 %)
# TRANSFERRING ||###############.........................||(111/314 MB:  35.53 %)
# TRANSFERRING ||###############.........................||(115/314 MB:  36.67 %)
# TRANSFERRING ||################........................||(119/314 MB:  37.82 %)
# TRANSFERRING ||################........................||(124/314 MB:  39.49 %)
# TRANSFERRING ||##############..........................||(110/314 MB:  34.97 %)
# TRANSFERRING ||#################.......................||(127/314 MB:  40.42 %)
# TRANSFERRING ||#################.......................||(127/314 MB:  40.52 %)
# TRANSFERRING ||#################.......................||(127/314 MB:  40.53 %)
# TRANSFERRING ||#################.......................||(127/314 MB:  40.64 %)
# TRANSFERRING ||#################.......................||(128/314 MB:  40.86 %)
# TRANSFERRING ||#################.......................||(130/314 MB:  41.48 %)
# TRANSFERRING ||#################.......................||(133/314 MB:  42.40 %)
# TRANSFERRING ||##################......................||(136/314 MB:  43.52 %)
# TRANSFERRING ||##################......................||(139/314 MB:  44.34 %)
# TRANSFERRING ||###################.....................||(143/314 MB:  45.67 %)
# TRANSFERRING ||###################.....................||(147/314 MB:  46.77 %)
# TRANSFERRING ||####################....................||(149/314 MB:  47.59 %)
# TRANSFERRING ||####################....................||(152/314 MB:  48.52 %)
# TRANSFERRING ||####################....................||(156/314 MB:  49.77 %)
# TRANSFERRING ||#####################...................||(160/314 MB:  51.16 %)
# TRANSFERRING ||######################..................||(165/314 MB:  52.68 %)
# TRANSFERRING ||######################..................||(168/314 MB:  53.60 %)
# TRANSFERRING ||#######################.................||(173/314 MB:  55.00 %)
# TRANSFERRING ||#######################.................||(177/314 MB:  56.48 %)
# TRANSFERRING ||######################..................||(165/314 MB:  52.53 %)
# TRANSFERRING ||########################................||(182/314 MB:  58.06 %)
# TRANSFERRING ||########################................||(183/314 MB:  58.42 %)
# TRANSFERRING ||########################................||(185/314 MB:  58.80 %)
# TRANSFERRING ||########################................||(186/314 MB:  59.17 %)
# TRANSFERRING ||########################................||(186/314 MB:  59.18 %)
# TRANSFERRING ||########################................||(186/314 MB:  59.18 %)
# TRANSFERRING ||########################................||(188/314 MB:  59.80 %)
# TRANSFERRING ||#########################...............||(189/314 MB:  60.37 %)
# TRANSFERRING ||#########################...............||(194/314 MB:  61.88 %)
# TRANSFERRING ||##########################..............||(199/314 MB:  63.31 %)
# TRANSFERRING ||##########################..............||(202/314 MB:  64.32 %)
# TRANSFERRING ||###########################.............||(206/314 MB:  65.59 %)
# TRANSFERRING ||#########################...............||(194/314 MB:  61.69 %)
# TRANSFERRING ||############################............||(213/314 MB:  67.90 %)
# TRANSFERRING ||############################............||(216/314 MB:  68.65 %)
# TRANSFERRING ||############################............||(219/314 MB:  69.77 %)
# TRANSFERRING ||#############################...........||(224/314 MB:  71.23 %)
# TRANSFERRING ||#############################...........||(226/314 MB:  72.11 %)
# TRANSFERRING ||##############################..........||(231/314 MB:  73.63 %)
# TRANSFERRING ||###############################.........||(236/314 MB:  75.12 %)
# TRANSFERRING ||###############################.........||(240/314 MB:  76.45 %)
# TRANSFERRING ||################################........||(243/314 MB:  77.51 %)
# TRANSFERRING ||################################........||(246/314 MB:  78.21 %)
# TRANSFERRING ||################################........||(246/314 MB:  78.41 %)
# TRANSFERRING ||################################........||(247/314 MB:  78.66 %)
# TRANSFERRING ||################################........||(247/314 MB:  78.81 %)
# TRANSFERRING ||################################........||(248/314 MB:  79.04 %)
# TRANSFERRING ||################################........||(249/314 MB:  79.43 %)
# TRANSFERRING ||################################........||(251/314 MB:  79.80 %)
# TRANSFERRING ||#################################.......||(252/314 MB:  80.17 %)
# TRANSFERRING ||#################################.......||(253/314 MB:  80.56 %)
# TRANSFERRING ||#################################.......||(254/314 MB:  80.93 %)
# TRANSFERRING ||#################################.......||(255/314 MB:  81.20 %)
# TRANSFERRING ||#################################.......||(255/314 MB:  81.21 %)
# TRANSFERRING ||#################################.......||(256/314 MB:  81.54 %)
# TRANSFERRING ||##################################......||(259/314 MB:  82.55 %)
# TRANSFERRING ||##################################......||(263/314 MB:  83.88 %)
# TRANSFERRING ||###################################.....||(268/314 MB:  85.20 %)
# TRANSFERRING ||###################################.....||(271/314 MB:  86.28 %)
# TRANSFERRING ||###################################.....||(273/314 MB:  86.86 %)
# TRANSFERRING ||###################################.....||(270/314 MB:  85.86 %)
# TRANSFERRING ||####################################....||(275/314 MB:  87.50 %)
# TRANSFERRING ||####################################....||(276/314 MB:  87.88 %)
# TRANSFERRING ||####################################....||(277/314 MB:  88.27 %)
# TRANSFERRING ||####################################....||(279/314 MB:  88.70 %)
# TRANSFERRING ||####################################....||(282/314 MB:  89.76 %)
# TRANSFERRING ||#####################################...||(285/314 MB:  90.80 %)
# TRANSFERRING ||####################################....||(278/314 MB:  88.67 %)
# TRANSFERRING ||#####################################...||(287/314 MB:  91.38 %)
# TRANSFERRING ||#####################################...||(288/314 MB:  91.76 %)
# TRANSFERRING ||######################################..||(293/314 MB:  93.14 %)
# TRANSFERRING ||######################################..||(296/314 MB:  94.23 %)
# TRANSFERRING ||######################################..||(298/314 MB:  94.91 %)
# TRANSFERRING ||#######################################.||(299/314 MB:  95.19 %)
# TRANSFERRING ||#######################################.||(299/314 MB:  95.19 %)
# TRANSFERRING ||######################################..||(295/314 MB:  93.92 %)
# TRANSFERRING ||#######################################.||(299/314 MB:  95.19 %)
# TRANSFERRING ||#######################################.||(299/314 MB:  95.31 %)
# TRANSFERRING ||#######################################.||(301/314 MB:  95.78 %)
# TRANSFERRING ||#######################################.||(303/314 MB:  96.60 %)
# TRANSFERRING ||#######################################.||(305/314 MB:  97.00 %)
# TRANSFERRING ||#######################################.||(306/314 MB:  97.42 %)
# TRANSFERRING ||########################################||(306/314 MB:  97.53 %)
# TRANSFERRING ||########################################||(308/314 MB:  97.93 %)
# TRANSFERRING ||########################################||(309/314 MB:  98.49 %)
# TRANSFERRING ||########################################||(310/314 MB:  98.69 %)
# TRANSFERRING ||########################################||(311/314 MB:  98.92 %)
# TRANSFERRING ||########################################||(314/314 MB:  99.96 %)
# TRANSFERRING ||########################################||(314/314 MB:  99.96 %)
# TRANSFERRING ||########################################||(314/314 MB: 100.00 %)
# TRANSFERRING ||########################################||(314/314 MB: 100.00 %)
# Download finished: /content/drive/Shareddrives/Drive 2/Miraculous/[Toon-Nation] Miraculous - Tales of Ladybug & Cat Noir - S02E02 Dual Audio [Hindi+English] [1080p].mkv
# TRANSFERRING ||########################################||(314/314 MB: 100.00 %)
